# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __I actually work as telecommunications director__
# **I actually work as telecommunications director**

# %% [markdown]
# ***I am interested in data science, because of the tools I learnt to use and the application of those to explain and illustrate different business and society issues.***

# %% [markdown]
# ### The following code represent the sum of two integers

# %%
x=1+1
print (x)
# Out:
# 2

# %% [markdown]
# The folling list, will be completed by 4 different classic sport cars:
#
# - Ford Mustang 1969:
#
# ![This is a Mustang from 1969:](https://i.pinimg.com/originals/f1/3d/10/f13d10d7c1b010fa03849f5f83b549ab.jpg)
#
#
#
# - Chevrolet Chevelle 1969 SS:
#
# ![This is a Chevrolet Chevelle SS from 1969:](https://inthegaragemedia.com/wp-content/uploads/2022/08/004-1969-Chevy-Chevelle-side-view-1024x673.jpg)
#
#
#
# - Porsche 911 1970:
#
# ![This is a Porsche 911 from 1970:](https://richmonds.com.au/wp-content/uploads/2019/09/Porsche-911t-blue-coupe-2.jpg)
#
#
#
# - 1970 Ferrari Dino 246 GT:
#
# ![This is a 1970 Ferrari Dino 246 GT:](https://th.bing.com/th/id/R.8d01135810070e6110c692add7942fa1?rik=vLPnNWsvD%2bT0aQ&pid=ImgRaw&r=0)
#
#
#
#
# ### The follwing table display the horse power and Torque of each car:
#
#
# |The cars|Max Torque (Nm)|HP(Horse Power)|
# |--------|------|---------------|
# |Ford Mustang 1969|257|120|
# |Chevrolet Chevelle 1969 SS|319|155|
# |Porsche 911 1970|201|142|
# |1970 Ferrari Dino 246 GT|226|192|
