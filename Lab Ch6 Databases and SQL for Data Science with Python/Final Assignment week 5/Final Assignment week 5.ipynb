# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('FinalDB.db')

# %%
import csv

# %%
# %load_ext sql

# %%
con = sqlite3.connect("FinalDB.db")
cor = con.cursor()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///FinalDB.db
# Out:
# 'Connected: @FinalDB.db'

# %%
import ibm_db
import ibm_db_dbi

# %%
# Use Pandas to load the data available in the links above to dataframes. 
# Use these dataframes to load data on to the database FinalDB.db as required tables.
#Replace the placeholder values with the actuals for your Db2 Service Credentials
dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_hostname = "98538591-7217-4024-b027-8baa776ffad1.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_port = "30875"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_uid = "bxh40907"        # e.g. "abc12345"
dsn_pwd = "Dcw5KUdbHbtettE8"      # e.g. "7dBZ3wWt9XN6$o0J"
dsn_security = "SSL"              #i.e. "SSL"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  bxh40907 on host:  98538591-7217-4024-b027-8baa776ffad1.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud

# %%
data = ibm_db_dbi.Connection(conn)
df_CENSUS_DATA = pd.read_sql('SELECT * FROM CENSUS_DATA', data)
df_CENSUS_DATA
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
df_CHICAGO_PUBLIC_SCHOOLS = pd.read_sql('SELECT * FROM CHICAGO_PUBLIC_SCHOOLS', data)
df_CHICAGO_PUBLIC_SCHOOLS
# Out:
#      SCHOOL_ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL         STREET_ADDRESS     CITY STATE  \
# 0                                   ES        615 W Kemper Pl  Chicago    IL
# ...

# %%
df_CHICAGO_CRIME_DATA = pd.read_sql('SELECT * FROM CHICAGO_CRIME_DATA', data)
df_CHICAGO_CRIME_DATA
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
df_CENSUS_DATA.to_sql("CENSUS_DATA", con, if_exists='replace', index=False, method='multi')
df_CHICAGO_PUBLIC_SCHOOLS.to_sql("CHICAGO_PUBLIC_SCHOOLS", con, if_exists='replace', index=False, method='multi')
df_CHICAGO_CRIME_DATA.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method='multi')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#Problem 1
# %sql select count(*) from CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %%
#Problem 2
# %sql select "COMMUNITY_AREA_NAME", "PER_CAPITA_INCOME" from CENSUS_DATA where "PER_CAPITA_INCOME" < 11000 ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %%
#Problem 3
# %sql select CASE_NUMBER, DESCRIPTION from CHICAGO_CRIME_DATA where DESCRIPTION like '%minor%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'ILLEGAL CONSUMPTION BY MINOR')]

# %%
#Problem 4
# %sql select PRIMARY_TYPE, DESCRIPTION from CHICAGO_CRIME_DATA where PRIMARY_TYPE='KIDNAPPING' and DESCRIPTION like '%child%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %%
#Problem 5
# %sql select distinct PRIMARY_TYPE, LOCATION_DESCRIPTION from CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION like '%school%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %%
#Problem 6
# %sql select "Elementary, Middle, or High School", AVG("SAFETY_SCORE") AS SAFETY_SCORE from CHICAGO_PUBLIC_SCHOOLS group by "Elementary, Middle, or High School";
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Elementary, Middle, or High School', 49.50487329434698)]

# %%
#Problem 7
# %sql select "COMMUNITY_AREA_NAME", "PERCENT_HOUSEHOLDS_BELOW_POVERTY" from CENSUS_DATA order by "PERCENT_HOUSEHOLDS_BELOW_POVERTY" desc nulls last limit 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %%
#Problem 8
# %sql select WARD, COMMUNITY_AREA_NUMBER, count(COMMUNITY_AREA_NUMBER) from CHICAGO_CRIME_DATA \
GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(29.0, 25.0, 43)]

# %%
#Problem 9
# %sql select "COMMUNITY_AREA_NAME", "HARDSHIP_INDEX" from CENSUS_DATA  where "COMMUNITY_AREA_NAME" in \
   ( select "COMMUNITY_AREA_NAME" from CENSUS_DATA order by "HARDSHIP_INDEX" desc limit 1 );
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 98.0)]

# %%
#Problem 10
# %sql select "COMMUNITY_AREA_NAME" from CENSUS_DATA where "COMMUNITY_AREA_NUMBER" in \
(select count(COMMUNITY_AREA_NUMBER) from CHICAGO_CRIME_DATA GROUP BY COMMUNITY_AREA_NUMBER ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC LIMIT 1);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('South Shore',)]
